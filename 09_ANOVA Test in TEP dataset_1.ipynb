# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./data/faulty_training.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804999 entries, 0 to 804998
# Data columns (total 55 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   faultNumber    804999 non-null  int64
#  1   simulationRun  804999 non-null  int64
#  2   sample         804999 non-null  int64
#  3   xmeas_1        804999 non-null  float64
#  4   xmeas_2        804999 non-null  float64
#  5   xmeas_3        804999 non-null  float64
#  6   xmeas_4        804999 non-null  float64
#  7   xmeas_5        804999 non-null  float64
#  8   xmeas_6        804999 non-null  float64
#  9   xmeas_7        804999 non-null  float64
#  10  xmeas_8        804999 non-null  float64
#  11  xmeas_9        804999 non-null  float64
#  12  xmeas_10       804999 non-null  float64
#  13  xmeas_11       804999 non-null  float64
#  14  xmeas_12       804999 non-null  float64
#  15  xmeas_13       804999 non-null  float64
#  16  xmeas_14       804999 non-null  float64
# ...

# %%
data.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            1              1       1  0.25038   3674.0   4529.0   9.2320
# 1            1              1       2  0.25109   3659.4   4556.6   9.4264
# 2            1              1       3  0.25038   3660.3   4477.8   9.4426
# 3            1              1       4  0.24977   3661.3   4512.1   9.4776
# 4            1              1       5  0.29405   3679.0   4497.0   9.3381
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   26.889   42.402   2704.3  ...  53.744  24.657  62.544  22.137  39.935
# 1   26.721   42.576   2705.0  ...  53.414  24.588  59.259  22.084  40.176
# 2   26.875   42.070   2706.2  ...  54.357  24.666  61.275  22.380  40.244
# 3   26.758   42.063   2707.2  ...  53.946  24.725  59.856  22.277  40.257
# 4   26.889   42.650   2705.1  ...  53.658  28.797  60.717  21.947  39.144
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# ...

# %%
data.faultNumber.value_counts()
# should i make the same number of row??
# Out:
# 1     40500
# 9     40500
# 2     40500
# 3     40500
# 4     40500
# 5     40500
# 6     40500
# 7     40500
# 8     40500
# 10    40499
# 19    40000
# 11    40000
# 12    40000
# 13    40000
# 14    40000
# 15    40000
# 16    40000
# 17    40000
# 18    40000
# 20    40000
# Name: faultNumber, dtype: int64

# %%
data_prcs = data.drop(['simulationRun', 'sample'], axis=1)

# %%
data_prcs.head()
# Out:
#    faultNumber  xmeas_1  xmeas_2  xmeas_3  xmeas_4  xmeas_5  xmeas_6  xmeas_7  \
# 0            1  0.25038   3674.0   4529.0   9.2320   26.889   42.402   2704.3
# 1            1  0.25109   3659.4   4556.6   9.4264   26.721   42.576   2705.0
# 2            1  0.25038   3660.3   4477.8   9.4426   26.875   42.070   2706.2
# 3            1  0.24977   3661.3   4512.1   9.4776   26.758   42.063   2707.2
# 4            1  0.29405   3679.0   4497.0   9.3381   26.889   42.650   2705.1
#
#    xmeas_8  xmeas_9  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6   xmv_7  \
# 0   74.863   120.41  ...  53.744  24.657  62.544  22.137  39.935  42.323
# 1   75.000   120.41  ...  53.414  24.588  59.259  22.084  40.176  38.554
# 2   74.771   120.42  ...  54.357  24.666  61.275  22.380  40.244  38.990
# 3   75.224   120.39  ...  53.946  24.725  59.856  22.277  40.257  38.072
# 4   75.388   120.39  ...  53.658  28.797  60.717  21.947  39.144  41.955
#
#     xmv_8   xmv_9  xmv_10  xmv_11
# ...

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('xmeas_1 ~ C(faultNumber)', data=data_prcs).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq        df             F  PR(>F)
# C(faultNumber)  12080.939644      19.0  85189.822332     0.0
# Residual         6008.194065  804979.0           NaN     NaN

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                xmeas_1   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                 8.519e+04
# Date:                Sat, 02 Jul 2022   Prob (F-statistic):               0.00
# Time:                        00:39:30   Log-Likelihood:             8.2908e+05
# No. Observations:              804999   AIC:                        -1.658e+06
# Df Residuals:                  804979   BIC:                        -1.658e+06
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.7379      0.000   1718.952      0.000       0.737       0.739
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

mod = smf.ols(formula='faultNumber ~ xmeas_1 + xmeas_2', data=data_prcs)

# %%
res = mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            faultNumber   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                 2.696e+04
# Date:                Sat, 02 Jul 2022   Prob (F-statistic):               0.00
# Time:                        01:01:31   Log-Likelihood:            -2.5265e+06
# No. Observations:              804999   AIC:                         5.053e+06
# Df Residuals:                  804996   BIC:                         5.053e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.1099      0.534     26.416      0.000      13.063      15.157
# ...

# %%
data_prcs.columns
# Out:
# Index(['faultNumber', 'xmeas_1', 'xmeas_2', 'xmeas_3', 'xmeas_4', 'xmeas_5',
#        'xmeas_6', 'xmeas_7', 'xmeas_8', 'xmeas_9', 'xmeas_10', 'xmeas_11',
#        'xmeas_12', 'xmeas_13', 'xmeas_14', 'xmeas_15', 'xmeas_16', 'xmeas_17',
#        'xmeas_18', 'xmeas_19', 'xmeas_20', 'xmeas_21', 'xmeas_22', 'xmeas_23',
#        'xmeas_24', 'xmeas_25', 'xmeas_26', 'xmeas_27', 'xmeas_28', 'xmeas_29',
#        'xmeas_30', 'xmeas_31', 'xmeas_32', 'xmeas_33', 'xmeas_34', 'xmeas_35',
#        'xmeas_36', 'xmeas_37', 'xmeas_38', 'xmeas_39', 'xmeas_40', 'xmeas_41',
#        'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4', 'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8',
#        'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %%
formulas = 'faultNumber ~ xmeas_1 + xmeas_2 + xmeas_3 + xmeas_4 + xmeas_5 + xmeas_6 + xmeas_7 + xmeas_8 + xmeas_9 + xmeas_10 + xmeas_11 + xmeas_12 + xmeas_13 + xmeas_14 + xmeas_15 + xmeas_16 + xmeas_17 + xmeas_18 + xmeas_19 + xmeas_20 + xmeas_21 + xmeas_22 + xmeas_23 + xmeas_24 + xmeas_25 + xmeas_26 + xmeas_27 + xmeas_28 + xmeas_29 + xmeas_30 + xmeas_31 + xmeas_32 + xmeas_33 + xmeas_34 + xmeas_35 + xmeas_36 + xmeas_37 + xmeas_38 + xmeas_39 + xmeas_40 + xmeas_41 + xmv_1 + xmv_2 + xmv_3 + xmv_4 + xmv_5 + xmv_6 + xmv_7 + xmv_8 + xmv_9 + xmv_10 + xmv_11'

# %%
mod = smf.ols(formula=formulas, data=data_prcs)

# %%
res = mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            faultNumber   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                 1.017e+04
# Date:                Sat, 02 Jul 2022   Prob (F-statistic):               0.00
# Time:                        01:11:11   Log-Likelihood:            -2.3493e+06
# No. Observations:              804999   AIC:                         4.699e+06
# Df Residuals:                  804946   BIC:                         4.699e+06
# Df Model:                          52
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    861.9077    772.063      1.116      0.264    -651.309    2375.125
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols(formulas, data=data_prcs).fit()
anova_table = sm.stats.anova_lm(model, typ=2) # type 1,2,3 what is that ?????
anova_table
# i need to reverse the formula
# numeric should be tilda
# Out:
#                 sum_sq        df             F         PR(>F)
# xmeas_1   4.612375e+02       1.0     22.986215   1.631963e-06
# xmeas_2   2.132681e+03       1.0    106.284216   6.411199e-25
# xmeas_3   1.931387e+03       1.0     96.252539   1.014228e-22
# xmeas_4   1.314819e+05       1.0   6552.526030   0.000000e+00
# xmeas_5   2.649389e+02       1.0     13.203486   2.794463e-04
# xmeas_6   8.442091e+03       1.0    420.719706   1.797935e-93
# xmeas_7   2.594757e+05       1.0  12931.221556   0.000000e+00
# xmeas_8   2.884686e+03       1.0    143.761117   4.033158e-33
# xmeas_9   1.034355e+04       1.0    515.480563  4.423623e-114
# xmeas_10  1.330609e+03       1.0     66.312172   3.854164e-16
# xmeas_11  5.334081e+04       1.0   2658.290644   0.000000e+00
# xmeas_12  2.876635e+01       1.0      1.433599   2.311783e-01
# xmeas_13  4.833936e+05       1.0  24090.385221   0.000000e+00
# xmeas_14  4.601114e+00       1.0      0.229301   6.320428e-01
# ...
