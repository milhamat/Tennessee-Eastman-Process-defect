# %% [markdown]
# ## Imports

# %%
import pyreadr
import pandas as pd

# %% [markdown]
# ## The Data

# %%
path = './data/'

train_normal_path = 'TEP_FaultFree_Training.RData'
train_faulty_path = 'TEP_Faulty_Training.RData'

test_normal_path = 'TEP_FaultFree_Testing.RData'
test_faulty_path = 'TEP_Faulty_Testing.RData'

train_normal_complete = pyreadr.read_r(path + train_normal_path)['fault_free_training']
train_faulty_complete = pyreadr.read_r(path + train_faulty_path)['faulty_training']

test_normal_complete = pyreadr.read_r(path + test_normal_path)['fault_free_testing']
test_faulty_complete = pyreadr.read_r(path + test_faulty_path)['faulty_testing']

# %%
type(train_normal_complete)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Features shape

# %%
print('train_normal_complete shape: ',train_normal_complete.shape)
print('train_faulty_complete shape: ',train_faulty_complete.shape)
print('\n')
print('test_normal_complete shape: ',test_normal_complete.shape)
print('test_faulty_complete shape: ',test_faulty_complete.shape)
# Out:
# train_normal_complete shape:  (250000, 55)
# train_faulty_complete shape:  (5000000, 55)
#
#
# test_normal_complete shape:  (480000, 55)
# test_faulty_complete shape:  (9600000, 55)

# %% [markdown]
# ### How the data look like
# **Train Normal Complete**

# %%
train_normal_complete.head()
# ilham please find the information about some columns
# - faultNumber
# - simulationRun
# - sample
# and find it each 4 datasets 

# faultNumber = 0 means that there is normal and not faulty
# simulation = 1..2...
# samples = 1~500
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0          0.0            1.0       1  0.25038   3674.0   4529.0   9.2320
# 1          0.0            1.0       2  0.25109   3659.4   4556.6   9.4264
# 2          0.0            1.0       3  0.25038   3660.3   4477.8   9.4426
# 3          0.0            1.0       4  0.24977   3661.3   4512.1   9.4776
# 4          0.0            1.0       5  0.29405   3679.0   4497.0   9.3381
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   26.889   42.402   2704.3  ...  53.744  24.657  62.544  22.137  39.935
# 1   26.721   42.576   2705.0  ...  53.414  24.588  59.259  22.084  40.176
# 2   26.875   42.070   2706.2  ...  54.357  24.666  61.275  22.380  40.244
# 3   26.758   42.063   2707.2  ...  53.946  24.725  59.856  22.277  40.257
# 4   26.889   42.650   2705.1  ...  53.658  28.797  60.717  21.947  39.144
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# ...

# %%
train_normal_complete['faultNumber'].value_counts()
# Out:
# 0.0    250000
# Name: faultNumber, dtype: int64

# %%
# train_normal_complete['simulationRun'].value_counts()
# 500

# %%
# train_normal_complete['sample'].value_counts()
# 500

# %% [markdown]
# **Test Normal Complete**

# %%
test_normal_complete.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            0            1.0       1  0.25171   3672.4   4466.3   9.5122
# 1            0            1.0       2  0.25234   3642.2   4568.7   9.4145
# 2            0            1.0       3  0.24840   3643.1   4507.5   9.2901
# 3            0            1.0       4  0.25153   3628.3   4519.3   9.3347
# 4            0            1.0       5  0.21763   3655.8   4571.0   9.3087
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   27.057   42.473   2705.6  ...  54.494  24.527  59.710  22.357  40.149
# 1   26.999   42.586   2705.2  ...  53.269  24.465  60.466  22.413  39.956
# 2   26.927   42.278   2703.5  ...  54.000  24.860  60.642  22.199  40.074
# 3   26.999   42.330   2703.9  ...  53.860  24.553  61.908  21.981  40.141
# 4   26.901   42.402   2707.7  ...  53.307  21.775  61.891  22.412  37.696
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# ...

# %%
test_normal_complete['faultNumber'].value_counts()
# Out:
# 0    480000
# Name: faultNumber, dtype: int64

# %%
# test_normal_complete['simulationRun'].value_counts()
# 960

# %%
# test_normal_complete['sample'].value_counts()
# 500

# %% [markdown]
# **Train Faulty Complete**

# %%
train_faulty_complete.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            1            1.0       1  0.25038   3674.0   4529.0   9.2320
# 1            1            1.0       2  0.25109   3659.4   4556.6   9.4264
# 2            1            1.0       3  0.25038   3660.3   4477.8   9.4426
# 3            1            1.0       4  0.24977   3661.3   4512.1   9.4776
# 4            1            1.0       5  0.29405   3679.0   4497.0   9.3381
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   26.889   42.402   2704.3  ...  53.744  24.657  62.544  22.137  39.935
# 1   26.721   42.576   2705.0  ...  53.414  24.588  59.259  22.084  40.176
# 2   26.875   42.070   2706.2  ...  54.357  24.666  61.275  22.380  40.244
# 3   26.758   42.063   2707.2  ...  53.946  24.725  59.856  22.277  40.257
# 4   26.889   42.650   2705.1  ...  53.658  28.797  60.717  21.947  39.144
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# ...

# %%
# train_faulty_complete['faultNumber'].value_counts()
# in train faulty there 20 faultNumber
# and each faultnumber there 250.000

# %%
# train_faulty_complete['simulationRun'].value_counts()
# in the train faulty simulation there 1~343

# %%
# train_faulty_complete['sample'].value_counts()
# the train faulty sample has value 1~500
# and each sample has 10.000

# %% [markdown]
# **Test Faulty Complete**

# %%
test_faulty_complete.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            1            1.0       1  0.25171   3672.4   4466.3   9.5122
# 1            1            1.0       2  0.25234   3642.2   4568.7   9.4145
# 2            1            1.0       3  0.24840   3643.1   4507.5   9.2901
# 3            1            1.0       4  0.25153   3628.3   4519.3   9.3347
# 4            1            1.0       5  0.21763   3655.8   4571.0   9.3087
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   27.057   42.473   2705.6  ...  54.494  24.527  59.710  22.357  40.149
# 1   26.999   42.586   2705.2  ...  53.269  24.465  60.466  22.413  39.956
# 2   26.927   42.278   2703.5  ...  54.000  24.860  60.642  22.199  40.074
# 3   26.999   42.330   2703.9  ...  53.860  24.553  61.908  21.981  40.141
# 4   26.901   42.402   2707.7  ...  53.307  21.775  61.891  22.412  37.696
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# ...

# %%
# test_faulty_complete['faultNumber'].value_counts()
# there 1~20 and each has 480.000

# %%
# test_faulty_complete['simulationRun'].value_counts()
# there 1~343 and each has 19200

# %%
# test_faulty_complete['sample'].value_counts()
# in the sampel there 960 and each 10.00

# %% [markdown]
# ### Features Names
# **Train Normal Complete**

# %%
train_normal_complete.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %% [markdown]
# **Train Faulty Complete**

# %%
train_faulty_complete.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %% [markdown]
# **Test Normal Complete**

# %%
test_normal_complete.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %% [markdown]
# **Test Faulty Complete**

# %%
test_faulty_complete.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %% [markdown]
# ### Statistical Describe
# **Train Normal Complete**

# %%
train_normal_complete.describe()
# Out:
#        faultNumber  simulationRun         sample        xmeas_1  \
# count     250000.0  250000.000000  250000.000000  250000.000000
# mean           0.0     250.500000     250.500000       0.250482
# std            0.0     144.337567     144.337567       0.030873
# min            0.0       1.000000       1.000000       0.122450
# 25%            0.0     125.750000     125.750000       0.229770
# 50%            0.0     250.500000     250.500000       0.250510
# 75%            0.0     375.250000     375.250000       0.271200
# max            0.0     500.000000     500.000000       0.391740
#
#              xmeas_2       xmeas_3        xmeas_4        xmeas_5  \
# count  250000.000000  250000.00000  250000.000000  250000.000000
# mean     3663.785706    4508.81979       9.347101      26.902196
# std        34.006357      39.21542       0.085721       0.211485
# min      3511.800000    4336.90000       8.972700      25.951000
# ...

# %% [markdown]
# **Train Faulty Complete**

# %%
train_faulty_complete.describe()
# Out:
#         faultNumber  simulationRun        sample       xmeas_1       xmeas_2  \
# count  5.000000e+06   5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   1.050000e+01   2.505000e+02  2.505000e+02  2.613588e-01  3.663777e+03
# std    5.766282e+00   1.443373e+02  1.443373e+02  1.495384e-01  4.316941e+01
# min    1.000000e+00   1.000000e+00  1.000000e+00 -4.735000e-03  3.327400e+03
# 25%    5.750000e+00   1.257500e+02  1.257500e+02  2.183000e-01  3.636500e+03
# 50%    1.050000e+01   2.505000e+02  2.505000e+02  2.511300e-01  3.663300e+03
# 75%    1.525000e+01   3.752500e+02  3.752500e+02  2.832100e-01  3.690200e+03
# max    2.000000e+01   5.000000e+02  5.000000e+02  1.017500e+00  3.906700e+03
#
#             xmeas_3       xmeas_4       xmeas_5       xmeas_6       xmeas_7  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   4.506046e+03  9.370345e+00  2.690156e+01  4.236419e+01  2.723005e+03
# ...

# %% [markdown]
# **Test Normal Complete**

# %%
test_normal_complete.describe()
# Out:
#        faultNumber  simulationRun         sample        xmeas_1  \
# count     480000.0  480000.000000  480000.000000  480000.000000
# mean           0.0     250.500000     480.500000       0.250526
# std            0.0     144.337429     277.128268       0.031273
# min            0.0       1.000000       1.000000       0.122610
# 25%            0.0     125.750000     240.750000       0.229390
# 50%            0.0     250.500000     480.500000       0.250520
# 75%            0.0     375.250000     720.250000       0.271600
# max            0.0     500.000000     960.000000       0.390320
#
#              xmeas_2        xmeas_3        xmeas_4        xmeas_5  \
# count  480000.000000  480000.000000  480000.000000  480000.000000
# mean     3663.764171    4508.898696       9.346866      26.902165
# std        33.943033      39.398350       0.086148       0.211148
# min      3503.300000    4338.200000       8.936300      26.018000
# ...

# %% [markdown]
# **Test Faulty Complete**

# %%
test_faulty_complete.describe()
# Out:
#         faultNumber  simulationRun        sample       xmeas_1       xmeas_2  \
# count  9.600000e+06   9.600000e+06  9.600000e+06  9.600000e+06  9.600000e+06
# mean   1.050000e+01   2.505000e+02  4.805000e+02  2.565512e-01  3.665140e+03
# std    5.766282e+00   1.443373e+02  2.771280e+02  1.413868e-01  4.337049e+01
# min    1.000000e+00   1.000000e+00  1.000000e+00 -4.985500e-03  3.308400e+03
# 25%    5.750000e+00   1.257500e+02  2.407500e+02  2.191700e-01  3.637600e+03
# 50%    1.050000e+01   2.505000e+02  4.805000e+02  2.504100e-01  3.664000e+03
# 75%    1.525000e+01   3.752500e+02  7.202500e+02  2.801300e-01  3.690800e+03
# max    2.000000e+01   5.000000e+02  9.600000e+02  1.016800e+00  3.891700e+03
#
#             xmeas_3       xmeas_4       xmeas_5       xmeas_6       xmeas_7  \
# count  9.600000e+06  9.600000e+06  9.600000e+06  9.600000e+06  9.600000e+06
# mean   4.510175e+03  9.389582e+00  2.690135e+01  4.237570e+01  2.725131e+03
# ...

# %% [markdown]
# ### checking the missing values

# %%
trncp = train_normal_complete.isnull().sum()
cnt = 0
for i in trncp:
    if i == 1:
        cnt+=1
print(cnt)
# Out:
# 0

# %%
trfcp = train_faulty_complete.isnull().sum()
cnt = 0
for i in trfcp:
    if i == 1:
        cnt+=1
print(cnt)
# Out:
# 0

# %%
tsncp = test_normal_complete.isnull().sum()
cnt = 0
for i in trncp:
    if i == 1:
        cnt+=1
print(cnt)
# Out:
# 0

# %%
tsfcp = test_faulty_complete.isnull().sum()
cnt = 0
for i in trncp:
    if i == 1:
        cnt+=1
print(cnt)
# Out:
# 0

# %% [markdown]
# we can see that there is no missing value on the dataset

# %% [markdown]
# ### See the data types
# **Train Normal Complete**

# %%
train_normal_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 55 columns):
# faultNumber      250000 non-null float64
# simulationRun    250000 non-null float64
# sample           250000 non-null int32
# xmeas_1          250000 non-null float64
# xmeas_2          250000 non-null float64
# xmeas_3          250000 non-null float64
# xmeas_4          250000 non-null float64
# xmeas_5          250000 non-null float64
# xmeas_6          250000 non-null float64
# xmeas_7          250000 non-null float64
# xmeas_8          250000 non-null float64
# xmeas_9          250000 non-null float64
# xmeas_10         250000 non-null float64
# xmeas_11         250000 non-null float64
# xmeas_12         250000 non-null float64
# xmeas_13         250000 non-null float64
# xmeas_14         250000 non-null float64
# xmeas_15         250000 non-null float64
# xmeas_16         250000 non-null float64
# xmeas_17         250000 non-null float64
# ...

# %% [markdown]
# **Train Faulty Complete**

# %%
train_faulty_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 55 columns):
# faultNumber      int32
# simulationRun    float64
# sample           int32
# xmeas_1          float64
# xmeas_2          float64
# xmeas_3          float64
# xmeas_4          float64
# xmeas_5          float64
# xmeas_6          float64
# xmeas_7          float64
# xmeas_8          float64
# xmeas_9          float64
# xmeas_10         float64
# xmeas_11         float64
# xmeas_12         float64
# xmeas_13         float64
# xmeas_14         float64
# xmeas_15         float64
# xmeas_16         float64
# xmeas_17         float64
# xmeas_18         float64
# xmeas_19         float64
# xmeas_20         float64
# xmeas_21         float64
# xmeas_22         float64
# xmeas_23         float64
# xmeas_24         float64
# xmeas_25         float64
# xmeas_26         float64
# xmeas_27         float64
# xmeas_28         float64
# xmeas_29         float64
# ...

# %% [markdown]
# **Test Normal Complete**

# %%
test_normal_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480000 entries, 0 to 479999
# Data columns (total 55 columns):
# faultNumber      480000 non-null int32
# simulationRun    480000 non-null float64
# sample           480000 non-null int32
# xmeas_1          480000 non-null float64
# xmeas_2          480000 non-null float64
# xmeas_3          480000 non-null float64
# xmeas_4          480000 non-null float64
# xmeas_5          480000 non-null float64
# xmeas_6          480000 non-null float64
# xmeas_7          480000 non-null float64
# xmeas_8          480000 non-null float64
# xmeas_9          480000 non-null float64
# xmeas_10         480000 non-null float64
# xmeas_11         480000 non-null float64
# xmeas_12         480000 non-null float64
# xmeas_13         480000 non-null float64
# xmeas_14         480000 non-null float64
# xmeas_15         480000 non-null float64
# xmeas_16         480000 non-null float64
# xmeas_17         480000 non-null float64
# ...

# %% [markdown]
# **Test Faulty Complete**

# %%
test_faulty_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9600000 entries, 0 to 9599999
# Data columns (total 55 columns):
# faultNumber      int32
# simulationRun    float64
# sample           int32
# xmeas_1          float64
# xmeas_2          float64
# xmeas_3          float64
# xmeas_4          float64
# xmeas_5          float64
# xmeas_6          float64
# xmeas_7          float64
# xmeas_8          float64
# xmeas_9          float64
# xmeas_10         float64
# xmeas_11         float64
# xmeas_12         float64
# xmeas_13         float64
# xmeas_14         float64
# xmeas_15         float64
# xmeas_16         float64
# xmeas_17         float64
# xmeas_18         float64
# xmeas_19         float64
# xmeas_20         float64
# xmeas_21         float64
# xmeas_22         float64
# xmeas_23         float64
# xmeas_24         float64
# xmeas_25         float64
# xmeas_26         float64
# xmeas_27         float64
# xmeas_28         float64
# xmeas_29         float64
# ...
