# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # comparison dimension reduction with 30 n_components

# %%
pca30 = pd.read_csv('./experimental_result_csv/pca30.csv')
ipca30 = pd.read_csv('./experimental_result_csv/ipca30.csv')
tsvd30 = pd.read_csv('./experimental_result_csv/tsvd30.csv')
fa30 = pd.read_csv('./experimental_result_csv/fa30.csv')
fastica30 = pd.read_csv('./experimental_result_csv/fastica30.csv')
kpca30 = pd.read_csv('./experimental_result_csv/kpca30.csv')
nmf30 = pd.read_csv('./experimental_result_csv/nmf30.csv')
spca30 = pd.read_csv('./experimental_result_csv/spca30.csv')

# %%
# pca30.head()

# %%
# ipca30.head()

# %%
# tsvd30.head()

# %%
# pca30['errn'] = pca30['Unnamed: 0']

# %%
# plt.plot(pca30['PCA30'], marker='o')
# plt.xlim(1,20)

# %%
# plt.plot(pca30['PCA30'], marker='o', color='b', alpha=0.3)
# plt.plot(ipca30['IncPCA30'], marker='o', color='r', alpha=0.3)
# plt.plot(tsvd30['TSVD30'], marker='o', color='g', alpha=0.3)
# plt.xlim(1,20)

# %%
# fdr mean
dimred = pd.DataFrame()

# %%
algo_name = ['PCA', 'IncPCA', 'TSVD',  'FA', 'FastICA',  'KPCA',  'NMF',  'SPCA']

# %%
avg = [pca30.iloc[:, 1].mean()*100, ipca30.iloc[:, 1].mean()*100, tsvd30.iloc[:, 1].mean()*100, fa30.iloc[:, 1].mean()*100,
fastica30.iloc[:, 1].mean()*100, kpca30.iloc[:, 1].mean()*100, nmf30.iloc[:, 1].mean()*100, spca30.iloc[:, 1].mean()*100]

# %%
dimred['algo'] = algo_name

# %%
dimred['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pca30.iloc[:, 1], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipca30.iloc[:, 1], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvd30.iloc[:, 1], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(fa30.iloc[:, 1], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fastica30.iloc[:, 1], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpca30.iloc[:, 1], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmf30.iloc[:, 1], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spca30.iloc[:, 1], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Comparison 8 dimensional reduction for fault detection")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
dimred.T
# Out:
#              0         1     2         3         4         5       6         7
# algo       PCA    IncPCA  TSVD        FA   FastICA      KPCA     NMF      SPCA
# avg   58.99375  59.10625  59.0  28.25625  58.99375  58.99375  9.9125  56.41875

# %% [markdown]
# # Lag Adding Comparison

# %%
pcalg = pd.read_csv('./experimental_result_csv/pcalag.csv')
ipcalg = pd.read_csv('./experimental_result_csv/ipcalag.csv')
tsvdlg = pd.read_csv('./experimental_result_csv/tsvdlag.csv')
falg = pd.read_csv('./experimental_result_csv/falag.csv')
fasticalg = pd.read_csv('./experimental_result_csv/fasticalag.csv')
kpcalg = pd.read_csv('./experimental_result_csv/kpcalag.csv')
nmflg = pd.read_csv('./experimental_result_csv/nmflag.csv')
spcalg = pd.read_csv('./experimental_result_csv/spcalag.csv')

# %%
# pcalg.head(2)

# %% [markdown]
# ## Lag 1

# %%
l1 = pd.DataFrame()

avg = [pcalg.iloc[:, 1].mean()*100, ipcalg.iloc[:, 1].mean()*100, tsvdlg.iloc[:, 1].mean()*100, falg.iloc[:, 1].mean()*100,
fasticalg.iloc[:, 1].mean()*100, kpcalg.iloc[:, 1].mean()*100, nmflg.iloc[:, 1].mean()*100, spcalg.iloc[:, 1].mean()*100]

l1['algo'] = algo_name
l1['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pcalg.iloc[:, 1], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipcalg.iloc[:, 1], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvdlg.iloc[:, 1], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(falg.iloc[:, 1], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fasticalg.iloc[:, 1], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpcalg.iloc[:, 1], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmflg.iloc[:, 1], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spcalg.iloc[:, 1], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Adding lag 1")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
# fdr mean
l1.T
# Out:
#              0         1         2         3         4         5     6  \
# algo       PCA    IncPCA      TSVD        FA   FastICA      KPCA   NMF
# avg   59.75625  59.75625  59.88125  28.59375  59.75625  59.75625  9.95
#
#             7
# algo     SPCA
# avg   59.5125

# %% [markdown]
# ## Lag 2

# %%
l2 = pd.DataFrame()

avg = [pcalg.iloc[:, 2].mean()*100, ipcalg.iloc[:, 2].mean()*100, tsvdlg.iloc[:, 2].mean()*100, falg.iloc[:, 2].mean()*100,
fasticalg.iloc[:, 2].mean()*100, kpcalg.iloc[:, 2].mean()*100, nmflg.iloc[:, 2].mean()*100, spcalg.iloc[:, 2].mean()*100]

l2['algo'] = algo_name
l2['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pcalg.iloc[:, 2], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipcalg.iloc[:, 2], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvdlg.iloc[:, 2], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(falg.iloc[:, 2], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fasticalg.iloc[:, 2], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpcalg.iloc[:, 2], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmflg.iloc[:, 2], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spcalg.iloc[:, 2], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Adding lag 2")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
# fdr mean
l2.T
# Out:
#               0          1          2          3          4          5  \
# algo        PCA     IncPCA       TSVD         FA    FastICA       KPCA
# avg   61.051314  61.051314  60.913642  28.529412  61.051314  61.051314
#
#               6          7
# algo        NMF       SPCA
# avg   10.156446  60.888611

# %% [markdown]
# ## Lag 3

# %%
l3 = pd.DataFrame()

avg = [pcalg.iloc[:, 3].mean()*100, ipcalg.iloc[:, 3].mean()*100, tsvdlg.iloc[:, 3].mean()*100, falg.iloc[:, 3].mean()*100,
fasticalg.iloc[:, 3].mean()*100, kpcalg.iloc[:, 3].mean()*100, nmflg.iloc[:, 3].mean()*100, spcalg.iloc[:, 3].mean()*100]

l3['algo'] = algo_name
l3['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pcalg.iloc[:, 3], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipcalg.iloc[:, 3], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvdlg.iloc[:, 3], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(falg.iloc[:, 3], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fasticalg.iloc[:, 3], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpcalg.iloc[:, 3], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmflg.iloc[:, 3], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spcalg.iloc[:, 3], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Adding lag 3")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
# fdr mean
l3.T
# Out:
#              0         1          2         3         4         5          6  \
# algo       PCA    IncPCA       TSVD        FA   FastICA      KPCA        NMF
# avg   63.02005  63.02005  63.565163  28.58396  63.02005  63.02005  11.159148
#
#               7
# algo       SPCA
# avg   59.699248

# %% [markdown]
# # Filter Noise Adding Comparison

# %%
pcanf = pd.read_csv('./experimental_result_csv/pcanf.csv')
ipcanf = pd.read_csv('./experimental_result_csv/ipcanf.csv')
tsvdnf = pd.read_csv('./experimental_result_csv/tsvdnf.csv')
fanf = pd.read_csv('./experimental_result_csv/fanf.csv')
fasticanf = pd.read_csv('./experimental_result_csv/fasticanf.csv')
kpcanf = pd.read_csv('./experimental_result_csv/kpcanf.csv')
nmfnf = pd.read_csv('./experimental_result_csv/nmfnf.csv')
spcanf = pd.read_csv('./experimental_result_csv/spcanf.csv')

# %%
# pcanf.head(2)

# %% [markdown]
# ## 10 window for Filter Noise

# %%
w10 = pd.DataFrame()

avg = [pcanf.iloc[:, 1].mean()*100, ipcanf.iloc[:, 1].mean()*100, tsvdnf.iloc[:, 1].mean()*100, fanf.iloc[:, 1].mean()*100,
fasticanf.iloc[:, 1].mean()*100, kpcanf.iloc[:, 1].mean()*100, nmfnf.iloc[:, 1].mean()*100, spcanf.iloc[:, 1].mean()*100]

w10['algo'] = algo_name
w10['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pcanf.iloc[:, 1], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipcanf.iloc[:, 1], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvdnf.iloc[:, 1], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(fanf.iloc[:, 1], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fasticanf.iloc[:, 1], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpcanf.iloc[:, 1], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmfnf.iloc[:, 1], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spcanf.iloc[:, 1], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Adding Win 10")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
# fdr mean
w10.T
# Out:
#            0         1       2     3        4       5         6        7
# algo     PCA    IncPCA    TSVD    FA  FastICA    KPCA       NMF     SPCA
# avg   66.225  65.53125  66.225  34.3   66.225  66.225  17.03125  55.1625

# %% [markdown]
# ## 50 window for Filter Noise

# %%
w50 = pd.DataFrame()

avg = [pcanf.iloc[:, 1].mean()*100, ipcanf.iloc[:, 1].mean()*100, tsvdnf.iloc[:, 1].mean()*100, fanf.iloc[:, 1].mean()*100,
fasticanf.iloc[:, 1].mean()*100, kpcanf.iloc[:, 1].mean()*100, nmfnf.iloc[:, 1].mean()*100, spcanf.iloc[:, 1].mean()*100]

w50['algo'] = algo_name
w50['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pcanf.iloc[:, 2], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipcanf.iloc[:, 2], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvdnf.iloc[:, 2], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(fanf.iloc[:, 2], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fasticanf.iloc[:, 2], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpcanf.iloc[:, 2], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmfnf.iloc[:, 2], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spcanf.iloc[:, 2], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Adding Win 50")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
# fdr mean
w50.T
# Out:
#            0         1       2     3        4       5         6        7
# algo     PCA    IncPCA    TSVD    FA  FastICA    KPCA       NMF     SPCA
# avg   66.225  65.53125  66.225  34.3   66.225  66.225  17.03125  55.1625

# %% [markdown]
# ## 100 window for Filter Noise

# %%
w100 = pd.DataFrame()

avg = [pcanf.iloc[:, 1].mean()*100, ipcanf.iloc[:, 1].mean()*100, tsvdnf.iloc[:, 1].mean()*100, fanf.iloc[:, 1].mean()*100,
fasticanf.iloc[:, 1].mean()*100, kpcanf.iloc[:, 1].mean()*100, nmfnf.iloc[:, 1].mean()*100, spcanf.iloc[:, 1].mean()*100]

w100['algo'] = algo_name
w100['avg'] = avg

# %%
plt.figure(figsize=(11,6), dpi=216)
plt.plot(pcanf.iloc[:, 3], marker='o', color='blue', alpha=0.4, label='PCA')
plt.plot(ipcanf.iloc[:, 3], marker='o', color='green', alpha=0.4, label='IncPCA')
plt.plot(tsvdnf.iloc[:, 3], marker='o', color='red', alpha=0.4, label='TruncSVD')
plt.plot(fanf.iloc[:, 3], marker='o', color='orange', alpha=0.4, label='FA')
plt.plot(fasticanf.iloc[:, 3], marker='o', color='brown', alpha=0.4, label='FastICA')
plt.plot(kpcanf.iloc[:, 3], marker='o', color='gray', alpha=0.4, label='KernelPCA')
plt.plot(nmfnf.iloc[:, 3], marker='o', color='purple', alpha=0.4, label='NMF')
plt.plot(spcanf.iloc[:, 3], marker='o', color='yellow', alpha=0.4, label='SparsePCA')
plt.legend(loc="upper right")
plt.xticks(range(20))
plt.title("Adding Win 100")
plt.xlabel("IDV's")
plt.ylabel("FDR")
plt.grid()
plt.show()

# %%
# fdr mean
w100.T
# Out:
#            0         1       2     3        4       5         6        7
# algo     PCA    IncPCA    TSVD    FA  FastICA    KPCA       NMF     SPCA
# avg   66.225  65.53125  66.225  34.3   66.225  66.225  17.03125  55.1625

# %% [markdown]
# # Comparison of the average performance

# %%
comp = pd.DataFrame()

# %%
comp['norm'] = dimred.iloc[:,1]
comp['lag1'] = l1.iloc[:,1]
comp['lag2'] = l2.iloc[:,1]
comp['lag3'] = l3.iloc[:,1]
comp['ws10'] = w10.iloc[:,1]
comp['ws50'] = w50.iloc[:,1]
comp['ws100'] = w100.iloc[:,1]

# %%
comp.index = algo_name

# %%
comp
# Out:
#              norm      lag1       lag2       lag3      ws10      ws50  \
# PCA      58.99375  59.75625  61.051314  63.020050  66.22500  66.22500
# IncPCA   59.10625  59.75625  61.051314  63.020050  65.53125  65.53125
# TSVD     59.00000  59.88125  60.913642  63.565163  66.22500  66.22500
# FA       28.25625  28.59375  28.529412  28.583960  34.30000  34.30000
# FastICA  58.99375  59.75625  61.051314  63.020050  66.22500  66.22500
# KPCA     58.99375  59.75625  61.051314  63.020050  66.22500  66.22500
# NMF       9.91250   9.95000  10.156446  11.159148  17.03125  17.03125
# SPCA     56.41875  59.51250  60.888611  59.699248  55.16250  55.16250
#
#             ws100
# PCA      66.22500
# IncPCA   65.53125
# TSVD     66.22500
# FA       34.30000
# FastICA  66.22500
# KPCA     66.22500
# NMF      17.03125
# SPCA     55.16250
